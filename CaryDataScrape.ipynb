# %%
import pandas as pd
import numpy as np
import re
import lxml
import seaborn as sns

from bs4 import BeautifulSoup
from requests import get
# %matplotlib inline

# %%
url_range = range(1,2000,50)
url_list = []
url_test = "https://www.imdb.com/search/title/?title_type=feature&start=1&ref_=adv_nxt"
for i in url_range:
    url_list.append("https://www.imdb.com/search/title/?title_type=feature&start=" + str(i) + "&ref_=adv_prv")

# %%
title = []
date = []
genre = []
rating = []
score = []
director = []
stars = []
for url in url_list:
    page = get(url)
    soup = BeautifulSoup(page.content, 'lxml')
    content = soup.find(id="main")
    articleTitle = soup.find("h1", class_="header").text.replace("\n","")
    frame = content.find_all("div", class_="lister-item mode-advanced")
    for i in range(0,50,1):    
        firstLine = frame[i].find("h3", class_="lister-item-header")
        title.append(firstLine.find("a").text)
        date.append(re.sub(r"[()]","", firstLine.find_all("span")[-1].text))
        genre.append(frame[i].find("span", class_="genre").text.rstrip().replace("\n","").split(","))
        try:
            rating.append(frame[i].find("strong").text)
        except:
            rating.append(0.0)
        try:
            score.append(frame[i].find("span", class_="metascore favorable").text.rstrip())
        except:
            try:
                score.append(frame[i].find("span", class_="metascore unfavorable").text.rstrip())
            except:
                try:
                    score.append(frame[i].find("span", class_="metascore mixed").text.rstrip())
                except:
                    score.append(0.0)
        cast = (frame[i].find("p", class_=""))
        try:
            casts = cast.text.replace("\n","").split('|')
            casts = [x.strip() for x in casts]
            casts = [casts[i].replace(j, "") for i,j in enumerate(["Director:", "Stars:"])]
            director.append(casts[0])
            stars.append([x.strip() for x in casts[1].split(",")])
        except:
            casts = cast.text.replace("\n","").strip()
            director.append("No Director")
            stars.append([x.strip() for x in casts.split(",")])

    
     
column_names = ['Title','Date','Genre','Rating','Score','Director','Stars'] 
df = pd.DataFrame(list(zip(title,date,genre,rating,score,director,stars)),columns = column_names)

# %%
df.shape
# Out:
# (2000, 7)

# %%
url_boxoffice = "https://www.boxofficemojo.com/chart/top_lifetime_gross/"

# %%
page = get(url_boxoffice)
soup = BeautifulSoup(page.content, 'lxml')
rows = soup.findAll('tr')
i=0
titles = []
gross = []
for row in rows:
    if i == 0:
        i=1
    else:
        titles.append(row.find(class_='a-link-normal').text)
        gross.append(row.find(class_='a-text-right mojo-field-type-money').text)
gross
# Out:
# ['$936,662,225',
#  '$858,373,000',
#  '$760,507,625',
#  '$700,059,566',
#  '$678,815,482',
#  '$659,363,944',
#  '$652,270,625',
#  '$623,357,910',
#  '$620,181,382',
#  '$608,581,744',
#  '$543,638,043',
#  '$535,234,033',
#  '$532,177,324',
#  '$514,684,482',
#  '$504,014,165',
#  '$486,295,561',
#  '$477,020,655',
#  '$474,544,677',
#  '$460,998,507',
#  '$459,005,868',
#  '$448,139,099',
#  '$441,226,247',
#  '$435,110,554',
#  '$434,038,008',
#  '$426,829,839',
#  '$424,668,047',
#  '$423,315,812',
#  '$422,783,777',
#  '$417,719,760',
#  '$415,004,880',
#  '$412,563,408',
#  '$409,013,994',
#  '$408,084,349',
#  '$408,010,692',
#  '$407,022,860',
#  '$404,540,171',
#  '$402,828,120',
#  '$402,111,870',
#  '$400,738,009',
#  '$390,532,085',
#  '$389,813,101',
#  '$381,409,310',
#  '$380,843,261',
#  '$380,270,577',
#  '$377,845,905',
#  '$373,585,825',
#  '$370,782,930',
#  '$368,384,330',
#  '$368,065,385',
#  '$364,001,123',
#  '$363,070,709',
#  '$356,461,711',
# ...

# %%
# Out:
# Star Wars: Episode VII - The Force Awakens
# $936,662,225
# a

# %%
rows[1]
# Out:
# <tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">1</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt2488496/?ref_=bo_cso_table_1">Star Wars: Episode VII - The Force Awakens</a></td><td class="a-text-right mojo-field-type-money">$936,662,225</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2015/?ref_=bo_cso_table_1">2015</a></td></tr>

# %%
# Out:
# ['$936,662,225',
#  '$858,373,000',
#  '$760,507,625',
#  '$700,059,566',
#  '$678,815,482',
#  '$659,363,944',
#  '$652,270,625',
#  '$623,357,910',
#  '$620,181,382',
#  '$608,581,744',
#  '$543,638,043',
#  '$535,234,033',
#  '$532,177,324',
#  '$514,684,482',
#  '$504,014,165',
#  '$486,295,561',
#  '$477,020,655',
#  '$474,544,677',
#  '$460,998,507',
#  '$459,005,868',
#  '$448,139,099',
#  '$441,226,247',
#  '$435,110,554',
#  '$434,038,008',
#  '$426,829,839',
#  '$424,668,047',
#  '$423,315,812',
#  '$422,783,777',
#  '$417,719,760',
#  '$415,004,880',
#  '$412,563,408',
#  '$409,013,994',
#  '$408,084,349',
#  '$408,010,692',
#  '$407,022,860',
#  '$404,540,171',
#  '$402,828,120',
#  '$402,111,870',
#  '$400,738,009',
#  '$390,532,085',
#  '$389,813,101',
#  '$381,409,310',
#  '$380,843,261',
#  '$380,270,577',
#  '$377,845,905',
#  '$373,585,825',
#  '$370,782,930',
#  '$368,384,330',
#  '$368,065,385',
#  '$364,001,123',
#  '$363,070,709',
#  '$356,461,711',
# ...
